# %%
# %sql
create table dev_data.default.test(
  id int,
  name string
)
using delta

# %%
# %sql
insert into dev_data.default.test values(1,'Muni')

# %%
# %sql
select * from dev_data.default.test

# %%
# %sql
create volume dev_data.default.vol1

# %%
#drop table table_name
#drop volume volume_name

# %%
#testing_git....
#corrected

# %%
print("testing")
